# %% [markdown]
# # <span style="font-family: Cambria;">Preprocessing</span>

# %% [markdown]
# <span style="font-family: Cambria;">This document ties to describe some popular preprocessing activities which are so critical in text mining.
# Preprocessing is an essential phase in text processing that includes a set of activities.
# This document ties to describe some popular preprocessing activities which are so critical in text mining.
# Preprocessing is an essential phase in text processing that includes a set of activities.</span>

# %% [markdown]
# ## <span style="font-family: Cambria;">1)Tokenization</span>

# %% [markdown]
# <span style="font-family: Cambria;">In our tokenization project, we'll start by importing the necessary libraries and modules. These libraries will provide the tools and functions needed to work with text data and perform tokenization.</span>

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Kiarash
# [nltk_data]     Rahmani\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# <span style="font-family: Cambria;"> in this step read our text corpora from our local machine to strings</span>

# %%
import os

# Directory path containing the text files
directory_path = r'E:\Study\University\codes\Jupyter\Preprocessing in NLP\Preprocessing-Methods-NLP\Corpora'

# Initialize a list to store the text from each file
text_list = []

# Iterate through the files in the directory
for filename in os.listdir(directory_path):
    if filename.endswith(".txt"):
        file_path = os.path.join(directory_path, filename)
        with open(file_path, 'r') as file:
            text = file.read()
            text_list.append(text)

# The list text_list will now contain the text from all the .txt files in the directory

# %% [markdown]
# <span style="font-family: Cambria;">In this step, I developed a function to convert the contents of the text_list (which is a list of strings) into a single string. This transformation was necessary because the NLTK tokenizer is designed to tokenize strings, and I needed to prepare the data for tokenization. As a result, I stored the converted string in a variable named text.  </span>

# %%
# Python program to convert a list to string
 
def listToString(s):
 
    # initialize an empty string
    str1 = ""
 
    # traverse in the string
    for ele in s:
        str1 += ele
 
    # return string
    return str1
# Driver code
text = listToString(text_list)

# %% [markdown]
# <span style="font-family: Cambria;">In this step we use NLTK tokenizer and tokenize our input texts: </span>

# %%
nltk.word_tokenize(text)
# Out:
# ['what',
#  'are',
#  'recurrent',
#  'neural',
#  'networks',
#  '?',
#  'a',
#  'recurrent',
#  'neural',
#  'network',
#  '(',
#  'rnn',
#  ')',
#  'is',
#  'a',
#  'type',
#  'of',
#  'artificial',
#  'neural',
#  'network',
#  'which',
#  'uses',
#  'sequential',
#  'data',
#  'or',
#  'time',
#  'series',
#  'data',
#  '.',
#  'these',
#  'deep',
#  'learning',
#  'algorithms',
#  'are',
#  'commonly',
#  'used',
#  'for',
#  'ordinal',
#  'or',
#  'temporal',
#  'problems',
#  ',',
#  'such',
#  'as',
#  'language',
#  'translation',
#  ',',
#  'natural',
#  'language',
#  'processing',
#  '(',
#  'nlp',
#  ')',
#  ',',
#  'speech',
#  'recognition',
#  ',',
#  'and',
#  'image',
#  'captioning',
#  ';',
#  'they',
#  'are',
#  'incorporated',
#  'into',
#  'popular',
#  'applications',
#  'such',
#  'as',
#  'siri',
#  ',',
#  'voice',
#  'search',
#  ',',
#  'and',
#  'google',
#  'translate',
#  '.',
#  'like',
#  'feedforward',
#  'and',
#  'convolutional',
#  'neural',
# ...

# %% [markdown]
# ## <span style="font-family: Cambria;">2)Normalization</span>

# %% [markdown]
# <span style="font-family: Cambria;">Normalization or token normalization is the process of canonicalizing tokens so that matches occur despite superficial differences in the character sequences of the tokens</span>

# %% [markdown]
# <span style="font-family: Cambria;">We'll start by importing the necessary libraries and modules. These libraries will provide the tools and functions needed to work with text data and perform normalization.</span>

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Kiarash
# [nltk_data]     Rahmani\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Kiarash
# [nltk_data]     Rahmani\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Kiarash
# [nltk_data]     Rahmani\AppData\Roaming\nltk_data...
# True

# %% [markdown]
# <span style="font-family: Cambria;">In Text normalization we have some steps to do like:
# - Stop words removal
# - Lemmatization
# </span>

# %%
# Text normalization steps
text = text.lower()
tokens = word_tokenize(text)
tokens = [word for word in tokens if word not in stopwords.words('english')]
lemmatizer = WordNetLemmatizer()
normalized_text = [lemmatizer.lemmatize(word) for word in tokens]

# %% [markdown]
# ### <span style="font-family: Cambria;">2-1)Stop words removal</span>

# %% [markdown]
# <span style="font-family: Cambria;">output of our Stop words removal phase:</span>

# %%
print(tokens)
# Out:
# ['recurrent', 'neural', 'networks', '?', 'recurrent', 'neural', 'network', '(', 'rnn', ')', 'type', 'artificial', 'neural', 'network', 'uses', 'sequential', 'data', 'time', 'series', 'data', '.', 'deep', 'learning', 'algorithms', 'commonly', 'used', 'ordinal', 'temporal', 'problems', ',', 'language', 'translation', ',', 'natural', 'language', 'processing', '(', 'nlp', ')', ',', 'speech', 'recognition', ',', 'image', 'captioning', ';', 'incorporated', 'popular', 'applications', 'siri', ',', 'voice', 'search', ',', 'google', 'translate', '.', 'like', 'feedforward', 'convolutional', 'neural', 'networks', '(', 'cnns', ')', ',', 'recurrent', 'neural', 'networks', 'utilize', 'training', 'data', 'learn', '.', 'distinguished', '“', 'memory', '”', 'take', 'information', 'prior', 'inputs', 'influence', 'current', 'input', 'output', '.', 'traditional', 'deep', 'neural', 'networks', 'assume', 'inputs', 'outputs', 'independent', ',', 'output', 'recurrent', 'neural', 'networks', 'depend', 'prior',
# ...

# %% [markdown]
# ### <span style="font-family: Cambria;">2-2)Lemmatization</span>

# %% [markdown]
# <span style="font-family: Cambria;">output of our lemmatizer phase:</span>

# %%
print(normalized_text)
# Out:
# ['recurrent', 'neural', 'network', '?', 'recurrent', 'neural', 'network', '(', 'rnn', ')', 'type', 'artificial', 'neural', 'network', 'us', 'sequential', 'data', 'time', 'series', 'data', '.', 'deep', 'learning', 'algorithm', 'commonly', 'used', 'ordinal', 'temporal', 'problem', ',', 'language', 'translation', ',', 'natural', 'language', 'processing', '(', 'nlp', ')', ',', 'speech', 'recognition', ',', 'image', 'captioning', ';', 'incorporated', 'popular', 'application', 'siri', ',', 'voice', 'search', ',', 'google', 'translate', '.', 'like', 'feedforward', 'convolutional', 'neural', 'network', '(', 'cnns', ')', ',', 'recurrent', 'neural', 'network', 'utilize', 'training', 'data', 'learn', '.', 'distinguished', '“', 'memory', '”', 'take', 'information', 'prior', 'input', 'influence', 'current', 'input', 'output', '.', 'traditional', 'deep', 'neural', 'network', 'assume', 'input', 'output', 'independent', ',', 'output', 'recurrent', 'neural', 'network', 'depend', 'prior', 'element', '
# ...
